# %%
import pandas as pd

path = r"C:\Users\ANBAR\OneDrive - Danaher\Desktop\Will-Agency-42576-From-analytics-to-action-\Data\Movie_50k.csv"

df = pd.read_csv(path)

print("Shape:", df.shape)
print("\nColumns:")
print(df.columns.tolist())

display(pd.DataFrame({
    "column": df.columns,
    "dtype": df.dtypes.astype(str).values,
    "non_null": df.notna().sum().values,
    "nulls": df.isna().sum().values
}).sort_values("column").reset_index(drop=True))
# Out:
# Shape: (50000, 23)
#
# Columns:
# ['titleId', 'imdbUrl', 'originalTitle', 'titleType', 'releaseYear', 'runtimeMinutes', 'isAdult', 'imdbRating', 'numberOfVotes', 'allCountries', 'mainCountry', 'allLanguages', 'firstLanguage', 'englishTitle', 'topFiveActors', 'directors', 'writers', 'plotShort', 'plotMedium', 'plotLong', 'genres', 'keywords', 'production']
#             column    dtype  non_null  nulls
# 0     allCountries      str     50000      0
# 1     allLanguages      str     45727   4273
# 2        directors      str     46718   3282
# 3     englishTitle      str     15144  34856
# 4    firstLanguage      str     45727   4273
# 5           genres      str     45440   4560
# 6       imdbRating  float64     26352  23648
# 7          imdbUrl      str     50000      0
# 8          isAdult     bool     50000      0
# 9         keywords      str     26586  23414
# 10     mainCountry      str     50000      0
# 11   numberOfVotes  float64     26352  23648
# 12   originalTitle      str     50000      0
# 13        plotLong      str      2033  47967
# 14      plotMedium      str     18008  31992
# 15       plotShort      str     22778  27222
# 16      production      str     42863   7137
# 17     releaseYear  float64     45808   4192
# 18  runtimeMinutes  float64     36448  13552
# 19         titleId      str     50000      0
# 20       titleType      str     50000      0
# 21   topFiveActors      str     38820  11180
# 22         writers      str     39744  10256
